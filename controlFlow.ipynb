# %%
# control flow.

age = 20
if age < 18:
    print("Minor")
else:
    print("Adult")
    print("You are eligible to vote.")
# loop list with if



# loop through a list.
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    if fruit == "banana":
        print("Found banana!")
    else:
        print("Not banana.")
# user input and conditional.
name = input("Enter your name: ")
if name:
    print(f"Hello, {name}!")
else:
    print("Hello, stranger!")


# loop through a list.
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# while loop.
count = 0
while count < 5:
    print("Count:", count)
    count += 1
# function definition and call.
def greet(name):
    return f"Hello, {name}!"
print(greet("Alice"))

# class definition and instantiation.
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        return "Woof!"
my_dog = Dog("Buddy")
print(my_dog.name)
print(my_dog.bark())

# %%
# use
