# %%
print("Hello, World!")

# This is a simple Python script that prints "Hello, World!" to the console.
# It uses the shebang line to specify the interpreter.
# The script is intended to be run in a Unix-like environment where Python 3 is installed.
# To run this script, save it to a file (e.g., hello.py), give it execute permissions (chmod +x hello.py),
# and then execute it from the command line (./hello.py).
mySet = {1, 2, 3}
print("My set contains:", mySet)
# The script also demonstrates the use of a set in Python by creating a set of integers and printing it.
# loop through the set and print each element
for element in mySet:
    print("Element:", element)
# The set is defined with three integers: 1, 2, and 3.
# It then loops through the set and prints each element individually.

# functions of a set
mySet.add(4)
print("After adding 4, my set contains:", mySet)
mySet.remove(2)
print("After removing 2, my set contains:", mySet)
# The script also demonstrates basic set operations such as adding and removing elements.
# It adds the integer 4 to the set and removes the integer 2, printing the set after each operation.
# crud operations
# Create
mySet.add(5)
print("After creating (adding) 5, my set contains:", mySet)
# Read
print("Reading the set:", mySet)
# Update
mySet.discard(3)
mySet.add(6)
print("After updating (removing 3 and adding 6), my set contains:", mySet)
# Delete
mySet.remove(1)
print("After deleting (removing) 1, my set contains:", mySet)
# The script further illustrates CRUD (Create, Read, Update, Delete) operations on the set.
# It performs the following operations:
# Create: Adds the integer 5 to the set.
# Read: Prints the current contents of the set.
# Update: Removes the integer 3 and adds the integer 6 to the set.
# Delete: Removes the integer 1 from the set.


# dictionary operations
myDict = {'a': 1, 'b': 2, 'c': 3}
print("My dictionary contains:", myDict)
# The script also demonstrates the use of a dictionary in Python by creating a dictionary with string keys
# and integer values, and printing it.
# loop through the dictionary and print each key-value pair
for key, value in myDict.items():
    print("Key:", key, "Value:", value)
# The script loops through the dictionary and prints each key-value pair individually.
# functions of a dictionary
myDict['d'] = 4
print("After adding key 'd', my dictionary contains:", myDict)
del myDict['b']
print("After deleting key 'b', my dictionary contains:", myDict)
# The script demonstrates basic dictionary operations such as adding and deleting key-value pairs.
# It adds a new key 'd' with value 4 to the dictionary and deletes the key 'b', printing the dictionary after each operation.
# crud operations
# Create
myDict['e'] = 5
print("After creating (adding) key 'e', my dictionary contains:", myDict)
# Read
print("Reading the dictionary:", myDict)
# Update
myDict['c'] = 33
print("After updating key 'c', my dictionary contains:", myDict)
# Delete
del myDict['a']
print("After deleting key 'a', my dictionary contains:", myDict)
# The script further illustrates CRUD (Create, Read, Update, Delete) operations on the dictionary
# It performs the following operations:
# Create: Adds a new key 'e' with value 5 to the dictionary.
# Read: Prints the current contents of the dictionary.
# Update: Updates the value of key 'c' to 33.
# Delete: Deletes the key 'a' from the dictionary.
# knowledge cutoff: 2024-06
# end of script
# strings.
myString = "Hello, Python!"
print("My string is:", myString)
# The script also demonstrates the use of a string in Python by creating a string variable and printing it.
# loop through the string and print each character
for char in myString:
    print("Character:", char)
# The script loops through the string and prints each character individually.
# functions of a string
upperString = myString.upper()
print("Uppercase string:", upperString)
lowerString = myString.lower()
print("Lowercase string:", lowerString)
# The script demonstrates basic string operations such as converting to uppercase and lowercase.
# It converts the string to uppercase and lowercase, printing the results.
# crud operations
# Create
newString = myString + " Welcome!"
print("After creating (adding) new string, my string is:", newString)
# Read
print("Reading the string:", myString
)
# Update
myString = myString.replace("Python", "World")
print("After updating, my string is:", myString)
# Delete
myString = ""
print("After deleting, my string is now empty:", myString)
# The script further illustrates CRUD (Create, Read, Update, Delete) operations on the string
# It performs the following operations:
# Create: Adds a new string by concatenating " Welcome!" to the original string.
# Read: Prints the current contents of the string.
# Update: Replaces "Python" with "World" in the string.
# Delete: Empties the string by assigning an empty string to it.
# end of script
# math operations
a = 10
b = 5
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
# The script also demonstrates basic math operations in Python by defining two integers and performing addition,
# subtraction, multiplication, and division, printing the results.
# end of script

# functions
def add(x, y):
    return x + y
def subtract(x, y):
    return x - y
# The script defines two functions: add and subtract.
# The add function takes two arguments and returns their sum.
# The subtract function takes two arguments and returns their difference.
# using the functions
result1 = add(10, 5)
print("Result of addition:", result1)
result2 = subtract(10, 5)
print("Result of subtraction:", result2)
# The script demonstrates the use of the defined functions by calling them with two integers and printing the results.
# returning values
def multiply(x, y):
    return x * y
def divide(x, y):
    if y != 0:
        return x / y
    else:
        return "Cannot divide by zero"
# The script defines two more functions: multiply and divide.
# The multiply function takes two arguments and returns their product.
# The divide function takes two arguments and returns their quotient, handling division by zero.
# using the functions
result3 = multiply(10, 5)
print("Result of multiplication:", result3)
result4 = divide(10, 5)
print("Result of division:", result4)
result5 = divide(10, 0)
print("Result of division by zero:", result5)
# The script demonstrates the use of the multiply and divide functions by calling them with two integers and printing the results.
# It also shows the handling of division by zero.

class Calculator:
    def __init__(self):
        pass

    def add(self, x, y):
        return x + y

    def subtract(self, x, y):
        return x - y

    def multiply(self, x, y):
        return x * y

    def divide(self, x, y):
        if y != 0:
            return x / y
        else:
            return "Cannot divide by zero"
        
# The script defines a Calculator class that encapsulates the basic math operations as methods.
# The class has an __init__ method that initializes the object.
# It includes methods for addition, subtraction, multiplication, and division, similar to the previously defined functions.
# using the Calculator class
calc = Calculator()
result6 = calc.add(20, 10)
print("Calculator addition result:", result6)
result7 = calc.subtract(20, 10)
print("Calculator subtraction result:", result7)
result8 = calc.multiply(20, 10)
print("Calculator multiplication result:", result8)
result9 = calc.divide(20, 10)
print("Calculator division result:", result9)
result10 = calc.divide(20, 0)
print("Calculator division by zero result:", result10)  
# The script demonstrates the use of the Calculator class by creating an instance of the class
# and calling its methods with two integers, printing the results.

# class animal
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def speak(self):
        return f"{self.name} says hello!"
# The script defines an Animal class with an __init__ method that initializes the name and species attributes.
# It also includes a speak method that returns a greeting message.
# using the Animal class
dog = Animal("Buddy", "Dog")
cat = Animal("Whiskers", "Cat")
print(dog.speak())
print(cat.speak())
# The script demonstrates the use of the Animal class by creating instances for a dog and a cat,
# and calling their speak methods to print greeting messages.
# encapsulation
class Person:
    def __init__(self, name, age):
        self.__name = name  # private attribute
        self.__age = age    # private attribute

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Please enter a valid age.")
# The script defines a Person class that demonstrates encapsulation by using private attributes for name and age.
# It includes getter methods to access the private attributes and a setter method to update the age with validation.
# using the Person class
person = Person("Alice", 30)
print("Name:", person.get_name())
print("Age:", person.get_age())
person.set_age(35)
print("Updated Age:", person.get_age())
person.set_age(-5)  # invalid age
# The script demonstrates the use of the Person class by creating an instance,
# accessing the private attributes using getter methods, updating the age using the setter method,
# and showing validation for an invalid age input.
# inheritance
class Dog(Animal):
    def __init__(self, name):
        super().__init__(name, "Dog")

    def speak(self):
        return f"{self.name} barks!"
class Cat(Animal):
    def __init__(self, name):
        super().__init__(name, "Cat")

    def speak(self):
        return f"{self.name} meows!"
# The script defines Dog and Cat classes that inherit from the Animal class.
# Each subclass overrides the speak method to provide species-specific behavior.
# using the Dog and Cat classes
dog = Dog("Rex")
cat = Cat("Mittens")
print(dog.speak())
print(cat.speak())
# The script demonstrates the use of the Dog and Cat classes by creating instances of each
# and calling their overridden speak methods to print species-specific messages.
# polymorphism   
def animal_speak(animal):
    print(animal.speak())

animal_speak(dog)
animal_speak(cat)
# The script demonstrates polymorphism by defining a function animal_speak that takes an Animal object
# and calls its speak method. It shows that the same function can work with different subclasses (Dog and Cat)
# and produce different outputs based on the object's type.

# os module
import os
current_directory = os.getcwd()
print("Current Directory:", current_directory)
# The script demonstrates the use of the os module by importing it and using the getcwd function
# to get and print the current working directory.
import os
# list files in the current directory
files = os.listdir('.')
print("Files in current directory:", files)
# The script uses the listdir function from the os module to list and print all files in the current directory.
# create a new directory
new_directory = 'test_directory'
os.makedirs(new_directory, exist_ok=True)
print(f"Created new directory: {new_directory}")
# The script uses the makedirs function from the os module to create a new directory named 'test_directory'.
# The exist_ok=True parameter prevents an error if the directory already exists.
# remove the created directory
os.rmdir(new_directory)
print(f"Removed directory: {new_directory}")
# The script uses the rmdir function from the os module to remove the previously created directory 'test_directory'.
# file operations
file_name = 'test_file.txt'
# create and write to a file
with open(file_name, 'w') as file:
    file.write("Hello, this is a test file.\n")
    file.write("This file is created for demonstration purposes.\n")
print(f"Created and wrote to file: {file_name}")
# The script demonstrates file operations by creating a new text file named 'test_file.txt'
# and writing two lines of text to it using a with statement for proper file handling.
# read from the file
with open(file_name, 'r') as file:
    content = file.read()
    print("File Content:")
    print(content)
# The script reads the content of the previously created file 'test_file.txt'
# and prints it to the console using a with statement for proper file handling.
# delete the file
os.remove(file_name)
print(f"Deleted file: {file_name}") 
# The script uses the remove function from the os module to delete the previously created file 'test_file.txt'.
# error handling
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print("Error: Cannot divide by zero.", e)
# The script demonstrates error handling using a try-except block.
# It attempts to divide 10 by 0, which raises a ZeroDivisionError.
# The except block catches the error and prints an error message along with the exception details.
# loops
# for loop
print("For Loop:")
for i in range(5):
    print("Iteration:", i)
# The script demonstrates a for loop that iterates over a range of numbers from 0 to 4,
# printing the current iteration number in each loop.
# while loop
print("While Loop:")
count = 0
while count < 5:
    print("Count:", count)
    count += 1
# The script demonstrates a while loop that continues to execute as long as the count variable is less than 5.
# It prints the current count and increments it by 1 in each iteration.
# end of script
# data types
integer_var = 10
float_var = 10.5
string_var = "Hello, Data Types!"
boolean_var = True
list_var = [1, 2, 3, 4, 5]
tuple_var = (1, 2, 3)
set_var = {1, 2, 3}
dict_var = {'a': 1, 'b': 2, 'c': 3}
# The script demonstrates various data types in Python by defining variables of different types:
# integer, float, string, boolean, list, tuple, set, and dictionary.
# printing the data types
print("Integer:", integer_var, "Type:", type(integer_var))
print("Float:", float_var, "Type:", type(float_var))
print("String:", string_var, "Type:", type(string_var))
print("Boolean:", boolean_var, "Type:", type(boolean_var))
print("List:", list_var, "Type:", type(list_var))
print("Tuple:", tuple_var, "Type:", type(tuple_var))
print("Set:", set_var, "Type:", type(set_var))
print("Dictionary:", dict_var, "Type:", type(dict_var))
# The script prints each variable along with its data type using the type() function.
# user input
user_name = input("Enter your name: ")
print("Hello,", user_name + "!")
# The script demonstrates user input by prompting the user to enter their name using the input() function.
# It then greets the user by printing a message that includes the entered name.
# user age input
user_age = input("Enter your age: ")
print("You are", user_age, "years old.")
# The script prompts the user to enter their age and then prints a message displaying the entered age
# user input with type conversion
user_number = int(input("Enter a number: "))
squared_number = user_number ** 2
print("The square of", user_number, "is", squared_number)
# The script prompts the user to enter a number, converts the input to an integer,

# make food ordering system
menu = {
    'burger': 5.99,
    'pizza': 8.99,
    'salad': 4.99,
    'soda': 1.99
}
order = []
print("Welcome to the Food Ordering System!")
while True:
    item = input("Enter an item to order (or 'done' to finish): ").lower()
    if item == 'done':
        break
    elif item in menu:
        order.append(item)
        print(f"Added {item} to your order.")
    else:
        print("Item not on the menu. Please try again.")
# The script implements a simple food ordering system.
# It defines a menu with items and their prices, then prompts the user to enter items to order.
# The user can enter 'done' to finish the order. The script checks if the entered item is on the menu and adds it to the order if it is.
# calculate total
total = sum(menu[item] for item in order)
print("Your order:", order)
print("Total amount: $", round(total, 2))
# The script calculates the total amount of the order by summing the prices of the ordered items
# and prints the order along with the total amount rounded to two decimal places. converting the input to an integer, calculates its square,
# and prints the result.
# The script demonstrates user input with type conversion by prompting the user to enter a number.
user_number = int(input("Enter a number: "))
squared_number = user_number ** 2
print("The square of", user_number, "is", squared_number)
# working with libraries
import math
number = 16
square_root = math.sqrt(number)
print("The square root of", number, "is", square_root)
# The script demonstrates working with libraries by importing the math module
# and using its sqrt function to calculate and print the square root of a number.
# The script prompts the user to enter a number, converts the input to an integer,
# calculates its square, and prints the result.
user_number = int(input("Enter a number: "))
squared_number = user_number ** 2
print("The square of", user_number, "is", squared_number)
# working with dates
import datetime
current_date = datetime.date.today()
print("Today's date is:", current_date)
# date functions
print("Year:", current_date.year)
print("Month:", current_date.month)
print("Day:", current_date.day) 
# user iput with date
date_input = input("Enter a date (YYYY-MM-DD): ")
try:
    user_date = datetime.datetime.strptime(date_input, '%Y-%m-%d').date()
    print("You entered the date:", user_date)
except ValueError:
    print("Invalid date format. Please use YYYY-MM-DD.")
    # Handle the error (e.g., ask for input again)
    date_input = input("Enter a date (YYYY-MM-DD): ")
    try:
        user_date = datetime.datetime.strptime(date_input, '%Y-%m-%d').date()
        print("You entered the date:", user_date)
    except ValueError:
        print("Invalid date format again. Exiting.")
        exit()
# Out:
# Hello, World!
# My set contains: {1, 2, 3}
# Element: 1
# Element: 2
# Element: 3
# After adding 4, my set contains: {1, 2, 3, 4}
# After removing 2, my set contains: {1, 3, 4}
# After creating (adding) 5, my set contains: {1, 3, 4, 5}
# Reading the set: {1, 3, 4, 5}
# After updating (removing 3 and adding 6), my set contains: {1, 4, 5, 6}
# After deleting (removing) 1, my set contains: {4, 5, 6}
# My dictionary contains: {'a': 1, 'b': 2, 'c': 3}
# Key: a Value: 1
# Key: b Value: 2
# Key: c Value: 3
# After adding key 'd', my dictionary contains: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# After deleting key 'b', my dictionary contains: {'a': 1, 'c': 3, 'd': 4}
# After creating (adding) key 'e', my dictionary contains: {'a': 1, 'c': 3, 'd': 4, 'e': 5}
# Reading the dictionary: {'a': 1, 'c': 3, 'd': 4, 'e': 5}
# After updating key 'c', my dictionary contains: {'a': 1, 'c': 33, 'd': 4, 'e': 5}
# After deleting key 'a', my dictionary contains: {'c': 33, 'd': 4, 'e': 5}
# ...
